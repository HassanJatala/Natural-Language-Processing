# %%
import nltk
from nltk import word_tokenize, pos_tag

# %%
text = "I AM Loving the NLP Class!!! But sometimes, it Feels very CONFUSING !!!"
tokens = word_tokenize(text)
print(tokens)
# Out:
# I AM Loving the NLP Class!!! But sometimes, it Feels very CONFUSING !!!
# ['I', 'AM', 'Loving', 'the', 'NLP', 'Class', '!', '!', '!', 'But', 'sometimes', ',', 'it', 'Feels', 'very', 'CONFUSING', '!', '!', '!']

# %%
pos_tags = pos_tag(tokens)
print(pos_tags)
# Out:
# [('I', 'PRP'), ('AM', 'VBP'), ('Loving', 'VBG'), ('the', 'DT'), ('NLP', 'NNP'), ('Class', 'NN'), ('!', '.'), ('!', '.'), ('!', '.'), ('But', 'CC'), ('sometimes', 'RB'), (',', ','), ('it', 'PRP'), ('Feels', 'NNP'), ('very', 'RB'), ('CONFUSING', 'RB'), ('!', '.'), ('!', '.'), ('!', '.')]
